# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Define paths
project_path = "/content/drive/MyDrive/Voice project"
zip_path = f"{project_path}/mcv-scripted-en-v23.0.tar.gz"
extract_path = f"{project_path}/unzipped_dataset"

# Create a folder for extracted files (if not already)
# !mkdir -p "$extract_path"

# Move to project directory
# %cd "$project_path"

# Check available space before extraction
print("Checking available space...")
# !df -h

# %%
# Check available space before extraction
print("Checking available space")
# !df -h

.
print("\nExtracting dataset")
# !tar -xvf "$zip_path" -C "$extract_path"
# ------------------------------------------------

print("\nExtraction complete!")
print(f"Files extracted to: {extract_path}")

# Check space again after extraction
print("\nChecking available space after extraction:")
# !df -h "$extract_path"
